# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindaoctaviani7/Lindaoctaviani7-Machine-learning_Ganjil_TI3B_2026_244107020002/blob/main/Praktikum2_JS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load Library

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# Load Data

# %%
import pandas as pd

dpath = '/content/drive/MyDrive/Data Saya/semester 5/pembelajaran mesin/Titanic-Dataset.csv'
df = pd.read_csv(dpath)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# --- 2. Encoding fitur 'Sex' ---
df['Sex'] = df['Sex'].map({'male': 1, 'female': 0})
print("=== Hasil Setelah Encoding 'Sex' ===")
print(df[['Sex']].head(), "\n")
# Out:
# === Hasil Setelah Encoding 'Sex' ===
#    Sex
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1

# %% [markdown]
# Pre Processing Encoding "Cabin"

# %%
# --- 3. Encoding fitur 'Cabin' ---
df['Cabin'] = df['Cabin'].fillna('Unknown')
print("=== Hasil Setelah Fill NaN pada 'Cabin' ===")
print(df[['Cabin']].head(5), "\n")
df['Cabin'] = df['Cabin'].apply(lambda x: x[0] if x != 'Unknown' else 'U')
print("=== Hasil Ambil huruf pertama 'Cabin' (Deck) ===")
print(df[['Cabin']].head(5), "\n")
# Out:
# === Hasil Setelah Fill NaN pada 'Cabin' ===
#      Cabin
# 0  Unknown
# 1      C85
# 2  Unknown
# 3     C123
# 4  Unknown
#
# === Hasil Ambil huruf pertama 'Cabin' (Deck) ===
#   Cabin
# 0     U
# 1     C
# 2     U
# 3     C
# 4     U

# %% [markdown]
# Pre Processing Imputasi Data

# %%
# --- 4. Standarisasi fitur 'Age' ---
df['Age'] = df[['Age']].fillna(df['Age'].median())
print("=== Hasil Setelah Imputasi Data pada Usia dengan median ===")
print(df[['Age']].head(10), "\n")
# Out:
# === Hasil Setelah Imputasi Data pada Usia dengan median ===
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0
# 5  28.0
# 6  54.0
# 7   2.0
# 8  27.0
# 9  14.0

# %% [markdown]
# Pre Processing Standarisasi

# %%
scaler = StandardScaler()
df['Age'] = scaler.fit_transform(df[['Age']])
print("=== Hasil Setelah Standardisasi 'Age' ===")
print(df[['Age']].head(10), "\n")
# Out:
# === Hasil Setelah Standardisasi 'Age' ===
#         Age
# 0 -0.565736
# 1  0.663861
# 2 -0.258337
# 3  0.433312
# 4  0.433312
# 5 -0.104637
# 6  1.893459
# 7 -2.102733
# 8 -0.181487
# 9 -1.180535

# %% [markdown]
# Hasil setelah pre processing

# %%
# --- 5. Cek hasil akhir ---
print("=== Hasil Preprocessing (5 baris pertama) ===")
#print(df[['Sex', 'Cabin', 'Age']].head(5))
df.head()
# Out:
# === Hasil Preprocessing (5 baris pertama) ===
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    1 -0.565736      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.663861      1
# 2                             Heikkinen, Miss. Laina    0 -0.258337      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.433312      1
# 4                           Allen, Mr. William Henry    1  0.433312      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     U        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     U        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     U        S

# %% [markdown]
# seleksi fitur

# %%
df = df[['Survived', 'Pclass', 'Age', 'Sex', 'Cabin']]
df.head()
# Out:
#    Survived  Pclass       Age  Sex Cabin
# 0         0       3 -0.565736    1     U
# 1         1       1  0.663861    0     C
# 2         1       3 -0.258337    0     U
# 3         1       1  0.433312    0     C
# 4         0       3  0.433312    1     U
